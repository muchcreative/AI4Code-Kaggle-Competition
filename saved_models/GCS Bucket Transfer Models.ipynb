# %%
from google.colab import drive, auth

drive.mount('/content/drive')
auth.authenticate_user()
# Out:
# Mounted at /content/drive

# %%
project_id = 'positive-fuze-306921'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://md_code_rep/

# %%
# Double Check Model Loc
bucket_name = 'md_code_rep'
bucket_model_loc = 'checkpoints/gbert_gbert_multi_code_rep'

# !gsutil -m cp -r gs://{bucket_name}/{bucket_model_loc} '/content/drive/MyDrive/Colab Notebooks/ML Projects/Google AI4Code/saved_models'
print(f"All model files have been successfully benn from the GCS-Bucket at {bucket_name} to GDrive.")
# Out:
# Copying gs://md_code_rep/checkpoints/gbert_gbert_multi_code_rep/variables/variables.data-00000-of-00001...
# Copying gs://md_code_rep/checkpoints/gbert_gbert_multi_code_rep/variables/variables.index...
# Copying gs://md_code_rep/checkpoints/gbert_gbert_multi_code_rep/saved_model.pb...
# Copying gs://md_code_rep/checkpoints/gbert_gbert_multi_code_rep/keras_metadata.pb...
# All model files have been successfully benn from the GCS-Bucket at md_code_rep to GDrive.
