# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import re
import json
import requests
from pathlib import Path

import yaml
import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %%
# Load in cleared python ids
python_ids_path = '/content/drive/MyDrive/Colab Notebooks/ML Projects/Google AI4Code/data/jup_python_ids/extra_ids_240000_500000.yaml'

with open(python_ids_path, 'r') as stream:
  python_ids = yaml.safe_load(stream)

python_paths = [Path(id) for id in python_ids]

# %% [markdown]
# ### Clean the Data and Filter Out Notebooks

# %%
def convert_list_to_text(text):
  if type(text) == str:
    return text
  else:
    text = " ".join(text)
  return text

def create_ids(length, count, prefix):
  return [prefix + str(i) for i in range(count, count+length)]

# %%
# Clean data we will add a rank file to each one
save_path = '/content/drive/MyDrive/Colab Notebooks/ML Projects/Google AI4Code/data/juypter_train'
empty_text_pattern = re.compile('^[ \t\n]*$')

doc_num = 0
count = 0

with requests.Session() as s:
  for python_path in tqdm(python_paths, desc='Cleaning, Filtering, and Saving Data Frames'):
    response = s.get(f'https://github-notebooks-update1.s3-eu-west-1.amazonaws.com/{python_path}')
    nb_file = response.json()

    # Load in as DataFrame and Clean Up Columns
    current_doc = pd.DataFrame(nb_file['cells'])
    current_doc = current_doc.drop(columns=['metadata', 'outputs', 'execution_count'])
    current_doc = current_doc[(current_doc['cell_type'] == 'code') | (current_doc['cell_type'] == 'markdown')] 

    # Clean Text
    current_doc["source"] = current_doc["source"].apply(convert_list_to_text)
    current_doc['source'] = current_doc['source'].replace(empty_text_pattern, np.nan)
    current_doc = current_doc.dropna()

    # Setup Ranks
    current_doc = current_doc.reset_index(drop=True)
    current_doc['rank'] = current_doc.index
    current_doc = current_doc.sort_values(by=['cell_type', 'rank'])

    # Check for minimum cell type counts
    value_counts = current_doc['cell_type'].value_counts()
    try:
      code_count = value_counts['code']
      md_count = value_counts['markdown']
    except:
      continue

    # Shuffle markdowns
    md_rows = current_doc[code_count:]
    md_rows = md_rows.sample(frac=1)
    current_doc[code_count:] = md_rows

    # Create cell_ids
    code_ids = create_ids(code_count, count, prefix='jup_p2_code_id_')
    md_ids = create_ids(md_count, count, prefix='jup_p2_md_id_')
    current_doc['cell_id'] = code_ids + md_ids

    if md_count >= 1 and code_count >= 1:
      current_doc.to_csv(save_path + f'/jup_extra_p2_{doc_num}.csv', index=False)
      count += len(current_doc)
      doc_num += 1
# Out:
# Cleaning, Filtering, and Saving Data Frames:   0%|          | 0/82221 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
check_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML Projects/Google AI4Code/data/Juypter Extra/jup_extra_200.csv')
check_df
# Out:
#    cell_type                                             source  rank  \
# 0       code  ### Introducing dataset \n import numpy as np ...     3
# 1       code  # After loading packages & data : have a quick...     4
# 2       code                                 anime_users.head()     5
# 3       code  # We should at first merge both anime_names & ...     7
# 4       code  # Create a crosstable \n # Swow detail of anim...     8
# 5       code  from sklearn.decomposition import PCA \n pca =...    10
# 6       code         ps = pd.DataFrame(pca_samples)\n ps.head()    11
# 7       code              tocluster = pd.DataFrame(ps[[0,1,2]])    12
# 8       code            from mpl_toolkits.mplot3d import Axes3D    13
# 9       code  plt.rcParams['figure.figsize'] = (16, 9)\n \n ...    14
# 10      code  from sklearn.cluster import KMeans\n from skle...    18
# 11      code  plt.plot(range(0,8), inertia_list,'-o')\n plt....    19
# 12      code                    -------------------------------    21
# 13      code  ### Root file\n \n !ls -l\n \n print('\n')\n \...    22
# 14      code  ### Some basic librairies\n \n import pandas a...    23
# 15      code  ### Read files\n \n names = pd.read_csv("anime...    24
# 16      code                                     ratings.head()    25
# 17      code                                       names.head()    26
# 18      code  ### Feature engineering\n \n names.columns = [...    27
# 19      code  ### Merge two datasets\n \n anime = pd.merge(n...    28
# 20      code                                       anime.tail()    29
# 21      code  ### Cleaning data a bit\n \n #anime['anime_id'...    30
# 22      code  ### The dataset is quiet important which is ni...    31
# 23      code  #### Data is already super clean and well made...    32
# 24      code         anime[anime['user_id'] == 3].rating.mean()    33
# 25      code     anime[anime['user_id'] == 70585].rating.mean()    34
# 26      code  ### Calculate mean rating per user\n \n mean_u...    35
# 27      code    import seaborn as sns\n sns.pairplot(mean_user)    36
# 28      code  ### This gives us a distribution of ratings, w...    37
# 29      code  ### Test a seaborn plot : aim see the repartit...    38
# 30      code  #### Some people vote more than other, which c...    39
# 31      code  #### We can see that ratings are pretty high, ...    40
# 32      code                                       anime.info()    41
# 33      code                                   anime.describe()    42
# 34      code  ### Strat by building a model for ratings : \n...    43
# 35      code  ### Importing all needed librairies \n \n impo...    44
# 36      code                                       anime.tail()    45
# 37      code  Matrix = pd.pivot_table(anime,values='rating',...    46
# 38      code  P = Matrix.as_matrix()\n \n #### Classic resha...    47
# 39      code  ### Recommender itself by just sorting and ran...    48
# 40      code  ### Giving user id and number of movies to rec...    49
# 41      code  ### Or using inputs : \n \n print('Enter a use...    50
# 42      code  print('Enter a number of movie you want to rec...    51
# 43      code  ### Simulating the prediction\n \n already, pr...    52
# 44      code  ### Actual prediction \n \n print(f"For user {...    53
# 45      code  ### We would recommend the following list of m...    54
# 46      code                                 ### End of Jupyter    55
# 47  markdown  ### Algorithme de factorisation de matrice \n ...     2
# 48  markdown  ### Implementing a quick PCA just to get back ...     9
# 49  markdown  ## Objectifs : \n * Vous appliquerez au moins ...     1
# 50  markdown  # TP : MMGD - Projet \n ## Vue d'ensemble du p...     0
# 51  markdown  #### As we can see in this PCA the data seems ...    15
# 52  markdown  #### Implement a quick & easy to understand al...     6
# 53  markdown  ## KMeans could be seen as a first method to c...    16
# 54  markdown                 ## Building the Recommender System    20
# 55  markdown          ### Selecting number of k \n > Clustering    17
#
#              cell_id
# 0   jup_code_id_9409
# 1   jup_code_id_9410
# 2   jup_code_id_9411
# 3   jup_code_id_9412
# 4   jup_code_id_9413
# 5   jup_code_id_9414
# 6   jup_code_id_9415
# 7   jup_code_id_9416
# 8   jup_code_id_9417
# 9   jup_code_id_9418
# 10  jup_code_id_9419
# 11  jup_code_id_9420
# 12  jup_code_id_9421
# 13  jup_code_id_9422
# 14  jup_code_id_9423
# 15  jup_code_id_9424
# 16  jup_code_id_9425
# 17  jup_code_id_9426
# 18  jup_code_id_9427
# 19  jup_code_id_9428
# 20  jup_code_id_9429
# 21  jup_code_id_9430
# 22  jup_code_id_9431
# 23  jup_code_id_9432
# 24  jup_code_id_9433
# 25  jup_code_id_9434
# 26  jup_code_id_9435
# 27  jup_code_id_9436
# 28  jup_code_id_9437
# 29  jup_code_id_9438
# 30  jup_code_id_9439
# 31  jup_code_id_9440
# 32  jup_code_id_9441
# 33  jup_code_id_9442
# 34  jup_code_id_9443
# 35  jup_code_id_9444
# 36  jup_code_id_9445
# 37  jup_code_id_9446
# 38  jup_code_id_9447
# 39  jup_code_id_9448
# 40  jup_code_id_9449
# 41  jup_code_id_9450
# 42  jup_code_id_9451
# 43  jup_code_id_9452
# 44  jup_code_id_9453
# 45  jup_code_id_9454
# 46  jup_code_id_9455
# 47    jup_md_id_9409
# 48    jup_md_id_9410
# 49    jup_md_id_9411
# 50    jup_md_id_9412
# 51    jup_md_id_9413
# 52    jup_md_id_9414
# 53    jup_md_id_9415
# 54    jup_md_id_9416
# 55    jup_md_id_9417

# %%
# juypter_orders = {}
# for data_path in tqdm(juypter_paths, desc='Loading Juypter CSV Files'):
#   data = pd.read_csv(data_path, index_col='cell_id') 
#   id = data_path.stem
#   orders = list(data.sort_values(['rank']).index)
#   juypter_orders[id] = orders

# juypter_orders = pd.Series(juypter_orders)
# juypter_orders.to_json('/content/drive/MyDrive/Colab Notebooks/ML Projects/Google AI4Code/data/juypter_orders.json')
